# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('Doceree-HCP_Train_v2.csv')
df2 = pd.read_csv('Doceree-HCP_Test.csv')

# %%
df2.head()
# Out:
#        ID DEVICETYPE  PLATFORM_ID     BIDREQUESTIP  \
# 0  115501    Desktop            2   75.189.231.103
# 1  115502     Mobile            2    24.101.33.158
# 2  115503    Desktop            2  172.118.216.142
# 3  115504    Desktop            7   71.105.120.171
# 4  115505    Desktop            2     73.82.211.73
#
#                         USERPLATFORMUID       USERCITY  USERZIPCODE  \
# 0  0d5041ff-f0b6-4d1a-9ad7-0a29f7d485b4   Fayetteville      28305.0
# 1  c8396dd0-969f-4d99-a40b-b7bb1f516154  Conneaut Lake      16316.0
# 2  3c97a081-6518-43f8-9f26-369759cfb471         Covina      91724.0
# 3  3e2578c8-f794-41af-a38c-c5cfb3c0f014       Brooklyn      11226.0
# 4  ec2ae7ce-6a8c-4156-98a7-07203e60f483       Marietta      30062.0
#
#                                            USERAGENT            PLATFORMTYPE  \
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6...  Online Medical Journal
# 1  Mozilla/5.0 (iPhone; CPU iPhone OS 15_6_1 like...  Online Medical Journal
# 2  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...  Online Medical Journal
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...  Online Medical Journal
# 4  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  Online Medical Journal
#
#   CHANNELTYPE                                                URL  \
# 0     Website  https://www.clinicaladvisor.com/home/features/...
# 1     Website  https://www.ophthalmologyadvisor.com/topics/ca...
# 2     Website  https://www.psychiatryadvisor.com/author/tori-...
# 3     Website  https://www.cureus.com/articles/105482-diverti...
# 4     Website  https://www.renalandurologynews.com/home/confe...
#
#                                             KEYWORDS
# 0  Family Practice|Drainage|Clinical|Dermatology|...
# 1  General|Clinical|Operative|Medicine|Cardiology...
# 2  Abortion|Anxiety Disorders|Apnea|False|Trauma|...
# 3  Health|Male|Neurological Surgery|Otolaryngolog...
# 4  chronic kidney disease|pain|nephrology|disease...

# %%
df1.head()
print(df1['ID'][len(df1)-1])
print(len(df1))
# Out:
# 114937
# 113937

# %%
df1.head()
# Out:
#      ID DEVICETYPE  PLATFORM_ID    BIDREQUESTIP  \
# 0  1001    Desktop            2    170.173.0.22
# 1  1002    Desktop            2   65.216.253.25
# 2  1003    Desktop            2    66.232.79.22
# 3  1004    Desktop            3  137.54.125.246
# 4  1005     Mobile            7  174.202.231.99
#
#                         USERPLATFORMUID     USERCITY  USERZIPCODE  \
# 0  6974dcaa-f932-480e-9fb5-c52e20e1393a     Portland      97206.0
# 1  c12f3f8f-8fcf-484a-90e1-1ac04db8cdcf    Arlington      22202.0
# 2  a698de4b-e200-46dd-b5fb-40402175ae18  New Meadows      83654.0
# 3  45967533-75c8-4fbd-a00c-e6ff20447aaa          NaN  229114624.0
# 4  a17e25be-532d-4cf5-b916-9308c8c3961f      Houston      77008.0
#
#                                            USERAGENT            PLATFORMTYPE  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  Online Medical Journal
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...  Online Medical Journal
# 2  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...  Online Medical Journal
# 3  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  Online Medical Journal
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 16_1_1 like...  Online Medical Journal
#
#   CHANNELTYPE                                                URL  \
# 0     Website  https://www.cancertherapyadvisor.com/home/canc...
# 1     Website  https://www.cancertherapyadvisor.com/home/deci...
# 2     Website  https://www.cancertherapyadvisor.com/home/canc...
# 3     Website  https://globalrph.com/medcalcs/warfarin-mainte...
# 4     Website  https://www.cureus.com/articles/58184-a-review...
#
#                                             KEYWORDS    TAXONOMY  IS_HCP
# 0  General|Endocrine|False|Medicine|Surgery|Urolo...         NaN     0.0
# 1  Bone Marrow|Radiography|Chronic|Oncology|Psych...         NaN     0.0
# 2  General|Endocrine|False|Medicine|Surgery|Urolo...         NaN     0.0
# 3  Dental|Total|Clinical|Pharmacology|Physicians|...  2084P0800X     1.0
# 4  Critical Care|Emergency Medicine|General Pract...         NaN     0.0

# %% [markdown]
# ### Merging the DataFrames

# %%
df = pd.concat([df1, df2], axis = 0)
print(len(df))
df.iloc[142429]
# Out:
# 142430
# ID                                                            143993
# DEVICETYPE                                                   Desktop
# PLATFORM_ID                                                        2
# BIDREQUESTIP                                          107.194.33.149
# USERPLATFORMUID                 f9b193b0-82b0-4ac8-b24a-5635401ca934
# USERCITY                                                  Wilmington
# USERZIPCODE                                                  28412.0
# USERAGENT          Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# PLATFORMTYPE                                  Online Medical Journal
# CHANNELTYPE                                                  Website
# URL                https://www.clinicalpainadvisor.com/regulatory...
# KEYWORDS           Medicine|General|Clinical|False|Urology|Total|...
# TAXONOMY                                                         NaN
# IS_HCP                                                           NaN
# Name: 28492, dtype: object

# %%
df = df.drop(columns=['USERCITY', 'USERZIPCODE'])
df.shape
# Out:
# (142430, 12)

# %%
from sklearn import preprocessing
sti = preprocessing.LabelEncoder()
enc_df = df.apply(sti.fit_transform)
enc_df
# Out:
#            ID  DEVICETYPE  PLATFORM_ID  BIDREQUESTIP  USERPLATFORMUID  \
# 0           0           0            1          7194            26134
# 1           1           0            1         21236            47842
# 2           2           0            1         21730            41220
# 3           3           0            2          4614            17268
# 4           4           1            6         11084            39893
# ...       ...         ...          ...           ...              ...
# 28488  142425           0            1         24832            29846
# 28489  142426           0            6         32308            40859
# 28490  142427           0            6          4602            42743
# 28491  142428           0            7         21781            54644
# 28492  142429           0            1          1960            61915
#
#        USERAGENT  PLATFORMTYPE  CHANNELTYPE   URL  KEYWORDS  TAXONOMY  IS_HCP
# 0           3100             3            0   746       475       207       0
# 1           2913             3            0   789       112       207       0
# 2           2913             3            0   746       475       207       0
# 3           3191             3            0   394       283       149       1
# 4           4371             3            0  1764       267       207       0
# ...          ...           ...          ...   ...       ...       ...     ...
# 28488       2949             3            0  5225      1059       207       2
# 28489       3068             3            0  1995      2230       207       2
# 28490       2863             3            0  2101      2234       207       2
# 28491       2264             3            0   414      2471       207       2
# 28492       3100             3            0  1412       742       207       2
#
# [142430 rows x 12 columns]

# %%
df[df['ID'] == 1004]
# Out:
#      ID DEVICETYPE  PLATFORM_ID    BIDREQUESTIP  \
# 3  1004    Desktop            3  137.54.125.246
#
#                         USERPLATFORMUID  \
# 3  45967533-75c8-4fbd-a00c-e6ff20447aaa
#
#                                            USERAGENT            PLATFORMTYPE  \
# 3  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  Online Medical Journal
#
#   CHANNELTYPE                                                URL  \
# 3     Website  https://globalrph.com/medcalcs/warfarin-mainte...
#
#                                             KEYWORDS    TAXONOMY  IS_HCP
# 3  Dental|Total|Clinical|Pharmacology|Physicians|...  2084P0800X     1.0

# %%
enc_df[enc_df['TAXONOMY'] == 149]
# Out:
#             ID  DEVICETYPE  PLATFORM_ID  BIDREQUESTIP  USERPLATFORMUID  \
# 3            3           0            2          4614            17268
# 83          83           1            1         27037            33629
# 90          90           0            1          7437            62912
# 103        103           1            1          4485            40096
# 108        108           0            1         21502             7219
# ...        ...         ...          ...           ...              ...
# 113911  113911           0            2          7009            24325
# 113927  113927           1            1         28314             9842
# 113933  113933           0            1           485            12564
# 113935  113935           1            1         25085            43464
# 113936  113936           1            1          3138            52049
#
#         USERAGENT  PLATFORMTYPE  CHANNELTYPE   URL  KEYWORDS  TAXONOMY  IS_HCP
# 3            3191             3            0   394       283       149       1
# 83           4159             3            0  3321       204       149       1
# 90           3011             3            0  2838       231       149       1
# 103          4045             3            0   919       852       149       1
# 108          2910             3            0   835       696       149       1
# ...           ...           ...          ...   ...       ...       ...     ...
# 113911       3179             3            0   397       110       149       1
# 113927       4045             3            0  5273       157       149       1
# 113933       3265             3            0   943        70       149       1
# 113935       4159             3            0  2620      1741       149       1
# 113936       4354             3            0  3979       504       149       1
#
# [7930 rows x 12 columns]

# %%
train_df = enc_df[0 : len(df1)]
train_df
# Out:
#             ID  DEVICETYPE  PLATFORM_ID  BIDREQUESTIP  USERPLATFORMUID  \
# 0            0           0            1          7194            26134
# 1            1           0            1         21236            47842
# 2            2           0            1         21730            41220
# 3            3           0            2          4614            17268
# 4            4           1            6         11084            39893
# ...        ...         ...          ...           ...              ...
# 113932  113932           0            1         24280             1271
# 113933  113933           0            1           485            12564
# 113934  113934           0            6         11676            38656
# 113935  113935           1            1         25085            43464
# 113936  113936           1            1          3138            52049
#
#         USERAGENT  PLATFORMTYPE  CHANNELTYPE   URL  KEYWORDS  TAXONOMY  IS_HCP
# 0            3100             3            0   746       475       207       0
# 1            2913             3            0   789       112       207       0
# 2            2913             3            0   746       475       207       0
# 3            3191             3            0   394       283       149       1
# 4            4371             3            0  1764       267       207       0
# ...           ...           ...          ...   ...       ...       ...     ...
# 113932       2828             3            0   908       155        69       1
# 113933       3265             3            0   943        70       149       1
# 113934       2891             3            0  1705       950       112       1
# 113935       4159             3            0  2620      1741       149       1
# 113936       4354             3            0  3979       504       149       1
#
# [113937 rows x 12 columns]

# %%
corr = train_df.corr()
corr
# Out:
#                        ID  DEVICETYPE  PLATFORM_ID  BIDREQUESTIP  \
# ID               1.000000   -0.001972     0.000548      0.005952
# DEVICETYPE      -0.001972    1.000000    -0.139708      0.077925
# PLATFORM_ID      0.000548   -0.139708     1.000000     -0.030542
# BIDREQUESTIP     0.005952    0.077925    -0.030542      1.000000
# USERPLATFORMUID  0.000323   -0.018691    -0.047263     -0.007451
# USERAGENT       -0.000795    0.199015    -0.008225      0.014850
# PLATFORMTYPE     0.001692   -0.057857    -0.324318      0.052124
# CHANNELTYPE           NaN         NaN          NaN           NaN
# URL             -0.002638    0.095569    -0.372605     -0.005481
# KEYWORDS        -0.003813   -0.187786     0.301249     -0.058139
# TAXONOMY        -0.001536   -0.104402     0.057853     -0.001318
# IS_HCP          -0.002449    0.102821     0.029981     -0.004547
#
#                  USERPLATFORMUID  USERAGENT  PLATFORMTYPE  CHANNELTYPE  \
# ID                      0.000323  -0.000795      0.001692          NaN
# DEVICETYPE             -0.018691   0.199015     -0.057857          NaN
# PLATFORM_ID            -0.047263  -0.008225     -0.324318          NaN
# BIDREQUESTIP           -0.007451   0.014850      0.052124          NaN
# USERPLATFORMUID         1.000000   0.001697      0.012434          NaN
# USERAGENT               0.001697   1.000000     -0.042069          NaN
# PLATFORMTYPE            0.012434  -0.042069      1.000000          NaN
# CHANNELTYPE                  NaN        NaN           NaN          NaN
# URL                     0.024692   0.058322      0.001808          NaN
# KEYWORDS                0.035188  -0.046052     -0.028133          NaN
# TAXONOMY                0.036441  -0.009262     -0.026473          NaN
# IS_HCP                 -0.036577   0.004022     -0.094282          NaN
#
#                       URL  KEYWORDS  TAXONOMY    IS_HCP
# ID              -0.002638 -0.003813 -0.001536 -0.002449
# DEVICETYPE       0.095569 -0.187786 -0.104402  0.102821
# PLATFORM_ID     -0.372605  0.301249  0.057853  0.029981
# BIDREQUESTIP    -0.005481 -0.058139 -0.001318 -0.004547
# USERPLATFORMUID  0.024692  0.035188  0.036441 -0.036577
# USERAGENT        0.058322 -0.046052 -0.009262  0.004022
# PLATFORMTYPE     0.001808 -0.028133 -0.026473 -0.094282
# CHANNELTYPE           NaN       NaN       NaN       NaN
# URL              1.000000 -0.104202 -0.128894  0.091359
# KEYWORDS        -0.104202  1.000000  0.171557 -0.194399
# TAXONOMY        -0.128894  0.171557  1.000000 -0.824261
# IS_HCP           0.091359 -0.194399 -0.824261  1.000000

# %%
featured_cols = ['DEVICETYPE', 'PLATFORM_ID', 'BIDREQUESTIP', 'USERPLATFORMUID', 'USERAGENT', 'PLATFORMTYPE', 'URL', 'KEYWORDS']
x = train_df[featured_cols]
y = train_df.IS_HCP
x.head()
# Out:
#    DEVICETYPE  PLATFORM_ID  BIDREQUESTIP  USERPLATFORMUID  USERAGENT  \
# 0           0            1          7194            26134       3100
# 1           0            1         21236            47842       2913
# 2           0            1         21730            41220       2913
# 3           0            2          4614            17268       3191
# 4           1            6         11084            39893       4371
#
#    PLATFORMTYPE   URL  KEYWORDS
# 0             3   746       475
# 1             3   789       112
# 2             3   746       475
# 3             3   394       283
# 4             3  1764       267

# %%
test_df = enc_df[len(df1) : ]
test_df = test_df[featured_cols]
test_df
# Out:
#        DEVICETYPE  PLATFORM_ID  BIDREQUESTIP  USERPLATFORMUID  USERAGENT  \
# 0               0            1         32162             3285       2706
# 1               1            1         16246            49642       4159
# 2               0            1          7459            15080       2863
# 3               0            6         25935            15468       2899
# 4               0            1         30842            58517       3011
# ...           ...          ...           ...              ...        ...
# 28488           0            1         24832            29846       2949
# 28489           0            6         32308            40859       3068
# 28490           0            6          4602            42743       2863
# 28491           0            7         21781            54644       2264
# 28492           0            1          1960            61915       3100
#
#        PLATFORMTYPE   URL  KEYWORDS
# 0                 3   941       421
# 1                 3  4740       465
# 2                 3  4778         0
# 3                 3  1440       546
# 4                 3  5164      1154
# ...             ...   ...       ...
# 28488             3  5225      1059
# 28489             3  1995      2230
# 28490             3  2101      2234
# 28491             3   414      2471
# 28492             3  1412       742
#
# [28493 rows x 8 columns]

# %% [markdown]
# ### Model Training

# %%
from sklearn.ensemble import RandomForestClassifier                    
model = RandomForestClassifier(n_estimators=3, criterion="entropy") 
model.fit(x, y)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=3)

# %%
y_pred = model.predict(test_df)
result = pd.DataFrame({'ID': df2['ID'],'Predicted': y_pred})
result
# Out:
#            ID  Predicted
# 0      115501          0
# 1      115502          1
# 2      115503          0
# 3      115504          0
# 4      115505          1
# ...       ...        ...
# 28488  143989          0
# 28489  143990          0
# 28490  143991          0
# 28491  143992          0
# 28492  143993          0
#
# [28493 rows x 2 columns]

# %%
result.to_csv('is_HCP_result.csv', index = False)

# %%
y_pred_train = model.predict(x)
result2 = pd.DataFrame({'Actual': y, 'Predicted': y_pred_train})
result2
# Out:
#         Actual  Predicted
# 0            0          0
# 1            0          0
# 2            0          0
# 3            1          1
# 4            0          0
# ...        ...        ...
# 113932       1          1
# 113933       1          1
# 113934       1          1
# 113935       1          1
# 113936       1          1
#
# [113937 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score
print("Accuracy: ", accuracy_score(y, y_pred_train))
# Out:
# Accuracy:  0.9979637870050994

# %% [markdown]
# ### Multiple Model Training

# %%
# for i in range(1, 31, 2):               
#     model = RandomForestClassifier(n_estimators=i, criterion="entropy")
#     model.fit(x, y)
#     y_pred_train = model.predict(x)
#     print("Accuracy for ", i, "th model: ", accuracy_score(y, y_pred_train))

# %%
df_is_hcp = train_df.loc[train_df['IS_HCP'] == 1]
df_is_hcp
# Out:
#             ID  DEVICETYPE  PLATFORM_ID  BIDREQUESTIP  USERPLATFORMUID  \
# 3            3           0            2          4614            17268
# 8            8           1            1           486            47148
# 21          21           0            2          2842            27015
# 29          29           0            6         16012             6131
# 35          35           0            1         30407            50658
# ...        ...         ...          ...           ...              ...
# 113932  113932           0            1         24280             1271
# 113933  113933           0            1           485            12564
# 113934  113934           0            6         11676            38656
# 113935  113935           1            1         25085            43464
# 113936  113936           1            1          3138            52049
#
#         USERAGENT  PLATFORMTYPE  CHANNELTYPE   URL  KEYWORDS  TAXONOMY  IS_HCP
# 3            3191             3            0   394       283       149       1
# 8            4045             3            0   776       627       151       1
# 21           3187             3            0   393       436       143       1
# 29           3227             3            0  1705       950       156       1
# 35           2847             3            0  5318       306        56       1
# ...           ...           ...          ...   ...       ...       ...     ...
# 113932       2828             3            0   908       155        69       1
# 113933       3265             3            0   943        70       149       1
# 113934       2891             3            0  1705       950       112       1
# 113935       4159             3            0  2620      1741       149       1
# 113936       4354             3            0  3979       504       149       1
#
# [34180 rows x 12 columns]

# %%
x2 = train_df[featured_cols]
y2 = train_df.TAXONOMY
x2
# Out:
#         DEVICETYPE  PLATFORM_ID  BIDREQUESTIP  USERPLATFORMUID  USERAGENT  \
# 0                0            1          7194            26134       3100
# 1                0            1         21236            47842       2913
# 2                0            1         21730            41220       2913
# 3                0            2          4614            17268       3191
# 4                1            6         11084            39893       4371
# ...            ...          ...           ...              ...        ...
# 113932           0            1         24280             1271       2828
# 113933           0            1           485            12564       3265
# 113934           0            6         11676            38656       2891
# 113935           1            1         25085            43464       4159
# 113936           1            1          3138            52049       4354
#
#         PLATFORMTYPE   URL  KEYWORDS
# 0                  3   746       475
# 1                  3   789       112
# 2                  3   746       475
# 3                  3   394       283
# 4                  3  1764       267
# ...              ...   ...       ...
# 113932             3   908       155
# 113933             3   943        70
# 113934             3  1705       950
# 113935             3  2620      1741
# 113936             3  3979       504
#
# [113937 rows x 8 columns]

# %%
model2 = RandomForestClassifier(n_estimators=3, criterion="entropy")
model2.fit(x2, y2)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=3)

# %%
test_df.iloc[1]
# Out:
# DEVICETYPE             1
# PLATFORM_ID            1
# BIDREQUESTIP       16246
# USERPLATFORMUID    49642
# USERAGENT           4159
# PLATFORMTYPE           3
# URL                 4740
# KEYWORDS             465
# Name: 1, dtype: int64

# %%
# for i in range(len(y_pred)):
#     if(y_pred[i] == 1):
#         print(model2.predict([test_df.iloc[i]]))

layer2_data = test_df[y_pred == 1]
y_pred_tax = model2.predict(layer2_data)
len(y_pred_tax)
# Out:
# 8355

# %%
le = preprocessing.LabelEncoder()
le.fit(df['TAXONOMY'])
decoded_labels = le.inverse_transform(y_pred_tax)
print(decoded_labels)
# Out:
# ['2084P0800X' '2084P0800X' '2084N0400X' ... '2084P0800X' '2084N0400X'
#  '207L00000X']

# %%
result_2 = pd.DataFrame({'ID': df2[y_pred == 1]['ID'],'Predicted': decoded_labels})
result_2
# Out:
#            ID   Predicted
# 1      115502  2084P0800X
# 4      115505  2084P0800X
# 10     115511  2084N0400X
# 12     115513  2084P0800X
# 29     115530  207R00000X
# ...       ...         ...
# 28470  143971         NaN
# 28472  143973  207X00000X
# 28474  143975  2084P0800X
# 28476  143977  2084N0400X
# 28480  143981  207L00000X
#
# [8355 rows x 2 columns]

# %%
result_2.to_csv('TAXONOMY_result.csv', index = False)
